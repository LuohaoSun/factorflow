# %% [markdown]
# # 使用五折交叉验证计算 shap 值, 并选择重要性最高的 2 个特征

# %%
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier

from factorflow import SelectFromModelShapCV

# %%
# 1. 准备数据
X, y = make_classification(n_samples=1000, n_features=20, n_informative=5, random_state=42)
X = pd.DataFrame(X, columns=pd.Index([f"feat_{i}" for i in range(20)]))

# %%
# 2. 初始化选择器
estimator = RandomForestClassifier(n_estimators=100, max_depth=3, random_state=42)
selector = SelectFromModelShapCV(
    estimator=estimator,
    task_type="classification",
    n_features_to_select=2,
    verbose=2,  # 设置为2以获取可视化结果
)

# %%
# 3. 拟合并转换, 通过副作用(绘图)查看shap分析结果
selector.fit_transform(X, y)
